# %%
import pandas as pd 
import numpy as np 
from sklearn import datasets
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import numpy as np
from numpy import linalg as LA
from random import randrange
from math import *
import random
from functools import reduce
import copy
import csv
import sys
import seaborn as sns
from operator import itemgetter
sns.set()

class Node():
    def __init__(self, X: pd.DataFrame, Y: list, min_elements=None, depth=None, condition=None):
        self.X = X
        self.Y = Y 
                    
        self.left = None
        self.right = None
        
        self.features = list(self.X.columns)
        self.min_elements = min_elements

        self.depth = depth if depth else 0
        self.condition = condition if condition else ""
        
        if len(Y) != 0:
            self.RSS = np.sum((Y - np.mean(Y)) ** 2) / len(Y)
        else:
            self.RSS = 0
    
    def get_leaf(self) -> int:
        if self.left == None and self.right == None:
            return 1
        return self.left.get_leaf() + self.right.get_leaf();
    
    def get_RSS_aux(self) -> float:
        if self.left == None and self.right == None:
            return self.RSS
        return self.left.get_RSS() + self.right.get_RSS();
    
    def get_RSS(self) -> float:
        return self.get_RSS_aux() / len(self.Y)
    
    def predict(self, X : pd.DataFrame) -> float:
        if self.left == None and self.right == None:
            return round(np.mean(self.Y), 3)
        
        left = self.left
        right = self.right
        
        condition = left.condition.split()
        feature, sign, number = condition[0], condition[1], float(condition[2])
        
        if sign == '<=':
            if X[feature] <= number:
                return left.predict(X)
            return right.predict(X)
        if sign == '==':
            if X[feature] == number:
                return left.predict(X)
            return right.predict(X)

    
    def findCut(self) -> tuple:
        data = self.X.copy()
        data['Y'] = self.Y

        RSS_MIN = self.RSS

        final_feature = None
        final_v = None

        for feature in self.features:
            X = data.sort_values(feature)
            
            if str(feature) in ['cylinders', 'origin', 'model_year']:
                cuts = X[feature].unique()
            else:
                cuts = np.convolve(X[feature], np.ones(2), 'valid') / 2    
                
            for v in cuts:
                leftY = X[X[feature] < v]['Y'].values
                rightY = X[X[feature] >= v]['Y'].values
                
                if len(leftY) != 0:
                    leftMean = np.mean(leftY)
                else:
                    leftMean = 0
                    
                if len(rightY) != 0:
                    rightMean = np.mean(rightY)
                else:
                    rightMean = 0
                    
                resLeft = leftY - leftMean 
                resRight = rightY - rightMean
                                
                RSS_TMP = (np.sum(resLeft ** 2) + np.sum(resRight ** 2)) / (len(resLeft) + len(resRight))
                         
                if RSS_TMP < RSS_MIN:
                    final_feature = feature
                    final_v = v

                    RSS_MIN = RSS_TMP

        return (final_feature, final_v)

    def createTree(self):
        data = self.X.copy()
        data['Y'] = self.Y

        if len(self.Y) > self.min_elements and self.RSS != 0:

            final_feature, final_v = self.findCut()

            if final_feature is not None:                
                if final_feature in ['cylinders', 'origin', 'model_year']:
                    leftData = data[data[final_feature] == final_v].copy()
                    rightData = data[data[final_feature] != final_v].copy()
                    text1 = "=="
                    text2 = "!="
                else:
                    leftData = data[data[final_feature] <= final_v].copy()
                    rightData = data[data[final_feature] > final_v].copy()
                    text1 = "<="
                    text2 = ">"
                
                left = Node(
                    leftData[self.features],
                    leftData['Y'].values.tolist(),
                    depth=self.depth + 1, 
                    min_elements=self.min_elements, 
                    condition=f"{final_feature} {text1} {round(final_v, 3)}"
                    )

                self.left = left 
                self.left.createTree()

                right = Node(
                    rightData[self.features],
                    rightData['Y'].values.tolist(), 
                    depth=self.depth + 1, 
                    min_elements=self.min_elements,
                    condition=f"{final_feature} {text2} {round(final_v, 3)}"
                    )

                self.right = right
                self.right.createTree()
                
    def printTree(self):
        const = int(self.depth * 2 ** 1.5)
        spaces = "*" * const
        
        if self.condition == '':
            print("Root")
        else:
            print(f"@{spaces} Condition: {self.condition}")
        
        print(f"{' ' * const}   | Prediction: {round(np.mean(self.Y), 3)}")   
        print(f"{' ' * const}   | RSS: {round(self.get_RSS(), 2)}")
        print(f"{' ' * const}   | Number of nodes: {len(self.Y)}")
        
        if self.left is not None: 
            self.left.printTree()
            self.right.printTree()

def getMinimumNode(node : Node, cost_root, isRoot = False):
    if node.left != None and node.right != None:
        (a_node, a_cost) = getMinimumNode(node.left, cost_root, False)
        (b_node, b_cost) = getMinimumNode(node.right, cost_root, False)
        
        g_ti = ( cost_root - node.get_RSS() ) / (node.get_leaf() - 1)
        
        if a_cost < 0:
            a_cost = cost_root + 1
        if b_cost < 0:
            b_cost = cost_root + 1
            
        if isRoot == False:
            minim = min(g_ti, a_cost, b_cost)
        else:
            minim = min(a_cost, b_cost)
                
        if minim == g_ti:
            return node, g_ti

        if minim == a_cost:
            return a_node, a_cost

        if minim == b_cost:
            return b_node, b_cost
    else:
        leaf = node.get_leaf()
        
        if leaf == 1:
            return node, cost_root + 1
        
        g_ti = ( cost_root - node.get_RSS() ) / (leaf - 1)
        return node, g_ti
    
def cutNode(root : Node, target : Node):
    if root.Y == target.Y:
        root.left= None
        root.right = None
        
        return True;
    else:
        if root.left != None and root.right != None:
            a = cutNode(root.left, target)
            if a == False:
                b = cutNode(root.right, target)
        else:
            return False
    return a or b
    
def AlphaPrunning(root : Node):
    forest = [(root, 0)]
    
    while root.get_leaf() > 2:
        node, alpha = getMinimumNode(root, root.get_RSS(), True)
        new_tree = copy.deepcopy(root);
        
        if root.get_RSS() <= alpha:
            break
        
        cutNode(new_tree, node)

        forest.append((new_tree, alpha))

        root = new_tree;
    
    return forest
    
def getDataSet(dataNumber):
    if dataNumber == 1:
        DATASET_NAME = "winequality-red.csv"
        CLASS = "CLASS"

        f_in = open(DATASET_NAME, 'r')
        csv_reader = csv.reader(f_in, delimiter=";")
        row = next(csv_reader)

        attributeNames = row[:-1]
        attributeNames = ['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar', 'chlorides',
                        'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density', 'pH', 'sulphates', 'alcohol']
        
        examples = []
        classes = []

        for row in csv_reader:
            *attributes, label = row
            
            attributes = [float(i) for i in attributes]
            
            classes.append(float(label))
            example = dict(zip(attributeNames, attributes))
            examples.append(example)

        f_in.close()

        return classes, attributeNames, examples
    if dataNumber == 2:
        DATASET_NAME = "auto-mpg.data"
        CLASS = "*MPG (miles per gallon)"
        
        f_in = open(DATASET_NAME, 'r')
        csv_reader = csv.reader(f_in, delimiter="\t", skipinitialspace=True)

        examples = []
        full_examples_l = []
        classes = list()

        ok = True
        for row in csv_reader:    
            *attributes, car_name = row
            attributes = str(*attributes).split()
            
            attributes = [float(i) if i != '?' else '?' for i in attributes]
            label = attributes[0]
            attributes = attributes[1:]
            
            if ok == True:
                ok = False
                attributeNames = ['cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model_year', 'origin']

            example = dict(zip(attributeNames, attributes))
            full_example = dict(zip(attributeNames, attributes))
            full_example[CLASS] = label
            
            if example["horsepower"] != '?':
                classes.append(label)
                examples.append(example)
                full_examples_l.append(full_example)

        f_in.close()

        return classes, attributeNames, examples
    
# def cross_validation_split(dataFrame, folds=3):
#     data = dataFrame.copy()
#     data = data.sample(frac = 1).reset_index(drop = True)
    
#     folds_list = list()
#     fold_size = int(len(data) / folds)
    
#     for i in range(folds):
#         fold = data.iloc[:fold_size]
#         data.drop(data.head(fold_size).index, inplace=True)
        
#         fold = fold.reset_index()
#         folds_list.append(fold)

#     return folds_list

def split_dataset(X, Y, attributes, train=.8):
    X['Y'] = Y
    attributes.append('Y')
    
    procent = int(len(X.index) * 0.8);
    
    X_train = X.iloc[:procent]
    X.drop(X.head(procent).index, inplace=True)
    
    X_test = X.reset_index()
    
    Y_train = X_train['Y'].values.tolist()
    Y_test = X_test['Y'].values.tolist()
    
    attributes.remove('Y')
    X_train = X_train[attributes]
    X_test = X_test[attributes]
    
    return X_train, Y_train, X_test, Y_test

def show_alpha_trees(forest):
    print("Numar de arbori obtinuti:", len(forest))
    for (tree, alpha) in forest:
        print("ALPHA =", alpha)
        print("COPAC-FRUNZE =", tree.get_leaf())
        tree.printTree()

def problema3():
    for i in range(1,3):
        print()
        if i == 1:
            print("WINEQUALITY-RED")
        else:
            print("AUTO-MPG")
        print()
        
        classes, attributes, X = getDataSet(i)

        X = np.array(X)
        Y = classes
        
        data = {}

        for attribute in attributes:
            data[attribute] = [X[0][attribute]]

        for ex in X[1:]:
            for attribute in attributes:
                data[attribute].append(ex[attribute])

        X = pd.DataFrame.from_dict(data)
        print(X)
        
        if i == 2:
            fig = plt.figure(figsize=(6, 5))
            plt.xlabel("x (feature)")
            plt.ylabel("y (output)")
            plt.title("HORSEPOWER")
            plt.plot(X['horsepower'], Y, 'co')
            plt.show()

            fig = plt.figure(figsize=(6, 5))
            plt.xlabel("x (feature)")
            plt.ylabel("y (output)")
            plt.title("WEIGHT")
            plt.plot(X['weight'], Y, 'mo')
            plt.show()

            fig = plt.figure(figsize=(6, 5))
            plt.xlabel("x (feature)")
            plt.ylabel("y (output)")
            plt.title("ACCELERATION")
            plt.plot(X['acceleration'], Y, 'bo')
            plt.show()

            fig = plt.figure(figsize=(6, 5))
            plt.xlabel("x (feature)")
            plt.ylabel("y (output)")
            plt.title("DISPLACEMENT")
            plt.plot(X['displacement'], Y, 'yo')
            plt.show()

            fig = plt.figure(figsize=(6, 5))
            plt.xlabel("x (feature)")
            plt.ylabel("y (output)")
            plt.title("CYLINDERS")
            plt.plot(X['cylinders'], Y, 'go')
            plt.show()

            fig = plt.figure(figsize=(6, 5))
            plt.xlabel("x (feature)")
            plt.ylabel("y (output)")
            plt.title("ORIGIN")
            plt.plot(X['origin'], Y, 'ro')
            plt.show()

            fig = plt.figure(figsize=(6, 5))
            plt.xlabel("x (feature)")
            plt.ylabel("y (output)")
            plt.title("MODEL YEAR")
            plt.plot(X['model_year'], Y, 'mo')
            plt.show()

        if i == 1:
            fig = plt.figure(figsize=(6, 5))
            plt.xlabel("x (feature)")
            plt.ylabel("y (output)")
            plt.title("fixed acidity")
            plt.plot(X['fixed_acidity'], Y, 'co')
            plt.show()

            fig = plt.figure(figsize=(6, 5))
            plt.xlabel("x (feature)")
            plt.ylabel("y (output)")
            plt.title("volatile acidity")
            plt.plot(X['volatile_acidity'], Y, 'mo')
            plt.show()

            fig = plt.figure(figsize=(6, 5))
            plt.xlabel("x (feature)")
            plt.ylabel("y (output)")
            plt.title("citric acid")
            plt.plot(X['citric_acid'], Y, 'bo')
            plt.show()

            fig = plt.figure(figsize=(6, 5))
            plt.xlabel("x (feature)")
            plt.ylabel("y (output)")
            plt.title("residual sugar")
            plt.plot(X['residual_sugar'], Y, 'yo')
            plt.show()

            fig = plt.figure(figsize=(6, 5))
            plt.xlabel("x (feature)")
            plt.ylabel("y (output)")
            plt.title("chlorides")
            plt.plot(X['chlorides'], Y, 'go')
            plt.show()

            fig = plt.figure(figsize=(6, 5))
            plt.xlabel("x (feature)")
            plt.ylabel("y (output)")
            plt.title("free sulfur dioxide")
            plt.plot(X['free_sulfur_dioxide'], Y, 'ro')
            plt.show()

            fig = plt.figure(figsize=(6, 5))
            plt.xlabel("x (feature)")
            plt.ylabel("y (output)")
            plt.title("total sulfur dioxide")
            plt.plot(X['total_sulfur_dioxide'], Y, 'mo')
            plt.show()
            
            fig = plt.figure(figsize=(6, 5))
            plt.xlabel("x (feature)")
            plt.ylabel("y (output)")
            plt.title("density")
            plt.plot(X['density'], Y, 'ro')
            plt.show()
            
            fig = plt.figure(figsize=(6, 5))
            plt.xlabel("x (feature)")
            plt.ylabel("y (output)")
            plt.title("pH")
            plt.plot(X['pH'], Y, 'bo')
            plt.show()
            
            fig = plt.figure(figsize=(6, 5))
            plt.xlabel("x (feature)")
            plt.ylabel("y (output)")
            plt.title("sulphates")
            plt.plot(X['sulphates'], Y, 'yo')
            plt.show()
            
            fig = plt.figure(figsize=(6, 5))
            plt.xlabel("x (feature)")
            plt.ylabel("y (output)")
            plt.title("alcohol")
            plt.plot(X['alcohol'], Y, 'go')
            plt.show()
            
        X_train, Y_train, X_test, Y_test = split_dataset(X, Y, attributes)

        root = Node(X_train, Y_train, min_elements=5)

        root.createTree()

        print("ROOT")

        root.printTree()

        print()
        forest = AlphaPrunning(root)

        saved_alpha = 0
        saved_tree = None
        SYS_MAX_VALUE = 9223372036854775807
        RSS = SYS_MAX_VALUE
        saved_y_hat = None
        
        errors_list = []
        alpha_list = []
                
        for (tree, alpha) in forest:
            y_hat = []
            for index, row in X_test.iterrows():
                y_hat.append(tree.predict(row))

            if tree.get_RSS() < RSS:
                RSS = tree.get_RSS()
                saved_alpha = alpha
                saved_tree = tree
                saved_y_hat = y_hat

            Y_HAT = np.array(y_hat)
            errors_list.append(sqrt(np.mean(np.square(Y_test - Y_HAT))))
            alpha_list.append(alpha)
        
        Y_test = np.array(Y_test)
        saved_y_hat = np.array(saved_y_hat)
        
        RMSE = sqrt(np.mean(np.square(Y_test - saved_y_hat)))
        print("RMSE FOR THE TREE CHOSE BY MIN RSS =", RMSE)
    
        fig, ax1 = plt.subplots(1,1);

        print("ALPHA LIST", alpha_list)
        ax1.plot(alpha_list, errors_list, 'ro-')
        ax1.set_ylabel("error")
        ax1.set_title("RMSE Loss for each alpha")
        ax1.set_xlabel("alpha")
    
        # Vezi arborii obtinuti si valorile alpha.
        show_alpha_trees(forest)
    
problema3()        
        
#     K-FOLD ...
#     folds = cross_validation_split(X, 10)
#     for fold in folds:
#         X = fold[attributes]
#         Y = fold['Y'].values.tolist()
#        
#         Y_hat = []
#         for index, row in X.iterrows():
#             Y_hat.append(root.predict(row))
#    
#         print(Y_hat, Y)
#
# Out:
# WINEQUALITY-RED
#
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1594     10.5
# 1595     11.2
# 1596     11.0
# 1597     10.2
# 1598     11.0
#
# [1599 rows x 11 columns]
# ROOT
# Root
#    | Prediction: 5.664
#    | RSS: 0.0
#    | Number of nodes: 1279
# @** Condition: alcohol <= 10.55
#      | Prediction: 5.387
#      | RSS: 0.0
#      | Number of nodes: 804
# @***** Condition: sulphates <= 0.575
#         | Prediction: 5.172
#         | RSS: 0.0
#         | Number of nodes: 303
# @******** Condition: density <= 1.001
#            | Prediction: 5.179
#            | RSS: 0.0
#            | Number of nodes: 302
# @*********** Condition: alcohol <= 9.75
#               | Prediction: 5.1
#               | RSS: 0.0
#               | Number of nodes: 210
# @************** Condition: pH <= 3.54
#                  | Prediction: 5.087
#                  | RSS: 0.0
#                  | Number of nodes: 207
# @**************** Condition: density <= 0.997
#                    | Prediction: 5.171
#                    | RSS: 0.0
#                    | Number of nodes: 111
# @******************* Condition: sulphates <= 0.525
#                       | Prediction: 5.037
#                       | RSS: 0.0
#                       | Number of nodes: 54
# @********************** Condition: citric_acid <= 0.055
#                          | Prediction: 4.7
#                          | RSS: 0.0
#                          | Number of nodes: 10
# @************************* Condition: fixed_acidity <= 7.8
#                             | Prediction: 4.875
#                             | RSS: 0.0
#                             | Number of nodes: 8
# @**************************** Condition: volatile_acidity <= 0.565
#                                | Prediction: 4.0
#                                | RSS: 0.0
#                                | Number of nodes: 1
# @**************************** Condition: volatile_acidity > 0.565
#                                | Prediction: 5.0
#                                | RSS: 0.0
#                                | Number of nodes: 7
# @************************* Condition: fixed_acidity > 7.8
#                             | Prediction: 4.0
#                             | RSS: 0.0
#                             | Number of nodes: 2
# @********************** Condition: citric_acid > 0.055
#                          | Prediction: 5.114
#                          | RSS: 0.0
#                          | Number of nodes: 44
# @************************* Condition: fixed_acidity <= 9.75
#                             | Prediction: 5.14
#                             | RSS: 0.0
#                             | Number of nodes: 43
# @**************************** Condition: residual_sugar <= 2.4
#                                | Prediction: 5.1
#                                | RSS: 0.0
#                                | Number of nodes: 40
# @******************************* Condition: free_sulfur_dioxide <= 4.5
#                                   | Prediction: 6.0
#                                   | RSS: 0.0
#                                   | Number of nodes: 1
# @******************************* Condition: free_sulfur_dioxide > 4.5
#                                   | Prediction: 5.077
#                                   | RSS: 0.0
#                                   | Number of nodes: 39
# @********************************* Condition: fixed_acidity <= 6.65
#                                     | Prediction: 5.5
#                                     | RSS: 0.12
#                                     | Number of nodes: 2
# @********************************* Condition: fixed_acidity > 6.65
#                                     | Prediction: 5.054
#                                     | RSS: 0.0
#                                     | Number of nodes: 37
# @************************************ Condition: residual_sugar <= 2.15
#                                        | Prediction: 5.03
#                                        | RSS: 0.0
#                                        | Number of nodes: 33
# @*************************************** Condition: density <= 0.997
#                                           | Prediction: 5.0
#                                           | RSS: 0.0
#                                           | Number of nodes: 26
# @*************************************** Condition: density > 0.997
#                                           | Prediction: 5.143
#                                           | RSS: 0.0
#                                           | Number of nodes: 7
# @****************************************** Condition: citric_acid <= 0.16
#                                              | Prediction: 6.0
#                                              | RSS: 0.0
#                                              | Number of nodes: 1
# @****************************************** Condition: citric_acid > 0.16
#                                              | Prediction: 5.0
#                                              | RSS: 0.0
#                                              | Number of nodes: 6
# @************************************ Condition: residual_sugar > 2.15
#                                        | Prediction: 5.25
#                                        | RSS: 0.05
#                                        | Number of nodes: 4
# @**************************** Condition: residual_sugar > 2.4
#                                | Prediction: 5.667
#                                | RSS: 0.07
#                                | Number of nodes: 3
# @************************* Condition: fixed_acidity > 9.75
#                             | Prediction: 4.0
#                             | RSS: 0.0
#                             | Number of nodes: 1
# @******************* Condition: sulphates > 0.525
#                       | Prediction: 5.298
#                       | RSS: 0.0
#                       | Number of nodes: 57
# @********************** Condition: chlorides <= 0.08
#                          | Prediction: 5.469
#                          | RSS: 0.0
#                          | Number of nodes: 32
# @************************* Condition: density <= 0.997
#                             | Prediction: 5.263
#                             | RSS: 0.0
#                             | Number of nodes: 19
# @**************************** Condition: chlorides <= 0.074
#                                | Prediction: 5.091
#                                | RSS: 0.01
#                                | Number of nodes: 11
# @******************************* Condition: citric_acid <= 0.235
#                                   | Prediction: 5.0
#                                   | RSS: 0.0
#                                   | Number of nodes: 9
# @******************************* Condition: citric_acid > 0.235
#                                   | Prediction: 5.5
#                                   | RSS: 0.12
#                                   | Number of nodes: 2
# @**************************** Condition: chlorides > 0.074
#                                | Prediction: 5.5
#                                | RSS: 0.0
#                                | Number of nodes: 8
# @******************************* Condition: residual_sugar <= 1.95
#                                   | Prediction: 5.2
#                                   | RSS: 0.03
#                                   | Number of nodes: 5
# @******************************* Condition: residual_sugar > 1.95
#                                   | Prediction: 6.0
#                                   | RSS: 0.0
#                                   | Number of nodes: 3
# @************************* Condition: density > 0.997
#                             | Prediction: 5.769
#                             | RSS: 0.0
#                             | Number of nodes: 13
# @**************************** Condition: total_sulfur_dioxide <= 19.0
#                                | Prediction: 7.0
#                                | RSS: 0.0
#                                | Number of nodes: 1
# @**************************** Condition: total_sulfur_dioxide > 19.0
#                                | Prediction: 5.667
#                                | RSS: 0.0
#                                | Number of nodes: 12
# @******************************* Condition: sulphates <= 0.555
#                                   | Prediction: 5.8
#                                   | RSS: 0.0
#                                   | Number of nodes: 10
# @********************************* Condition: fixed_acidity <= 9.85
#                                     | Prediction: 5.889
#                                     | RSS: 0.0
#                                     | Number of nodes: 9
# @************************************ Condition: total_sulfur_dioxide <= 117.0
#                                        | Prediction: 6.0
#                                        | RSS: 0.0
#                                        | Number of nodes: 8
# @************************************ Condition: total_sulfur_dioxide > 117.0
#                                        | Prediction: 5.0
#                                        | RSS: 0.0
#                                        | Number of nodes: 1
# @********************************* Condition: fixed_acidity > 9.85
#                                     | Prediction: 5.0
#                                     | RSS: 0.0
#                                     | Number of nodes: 1
# @******************************* Condition: sulphates > 0.555
#                                   | Prediction: 5.0
#                                   | RSS: 0.0
#                                   | Number of nodes: 2
# @********************** Condition: chlorides > 0.08
#                          | Prediction: 5.08
#                          | RSS: 0.0
#                          | Number of nodes: 25
# @************************* Condition: fixed_acidity <= 7.05
#                             | Prediction: 5.333
#                             | RSS: 0.01
#                             | Number of nodes: 6
# @**************************** Condition: fixed_acidity <= 6.85
#                                | Prediction: 5.0
#                                | RSS: 0.0
#                                | Number of nodes: 3
# @**************************** Condition: fixed_acidity > 6.85
#                                | Prediction: 5.667
#                                | RSS: 0.07
#                                | Number of nodes: 3
# @************************* Condition: fixed_acidity > 7.05
#                             | Prediction: 5.0
#                             | RSS: 0.0
#                             | Number of nodes: 19
# @**************** Condition: density > 0.997
#                    | Prediction: 4.99
#                    | RSS: 0.0
#                    | Number of nodes: 96
# @******************* Condition: density <= 1.0
#                       | Prediction: 4.968
#                       | RSS: 0.0
#                       | Number of nodes: 93
# @********************** Condition: fixed_acidity <= 6.95
#                          | Prediction: 6.0
#                          | RSS: 0.0
#                          | Number of nodes: 1
# @********************** Condition: fixed_acidity > 6.95
#                          | Prediction: 4.957
#                          | RSS: 0.0
#                          | Number of nodes: 92
# @************************* Condition: residual_sugar <= 1.7
#                             | Prediction: 4.0
#                             | RSS: 0.0
#                             | Number of nodes: 1
# @************************* Condition: residual_sugar > 1.7
#                             | Prediction: 4.967
#                             | RSS: 0.0
#                             | Number of nodes: 91
# @**************************** Condition: chlorides <= 0.072
#                                | Prediction: 4.6
#                                | RSS: 0.05
#                                | Number of nodes: 5
# @**************************** Condition: chlorides > 0.072
#                                | Prediction: 4.988
#                                | RSS: 0.0
#                                | Number of nodes: 86
# @******************************* Condition: density <= 0.999
#                                   | Prediction: 4.935
#                                   | RSS: 0.0
#                                   | Number of nodes: 62
# @********************************* Condition: residual_sugar <= 4.25
#                                     | Prediction: 4.951
#                                     | RSS: 0.0
#                                     | Number of nodes: 61
# @************************************ Condition: alcohol <= 9.05
#                                        | Prediction: 5.5
#                                        | RSS: 0.12
#                                        | Number of nodes: 2
# @************************************ Condition: alcohol > 9.05
#                                        | Prediction: 4.932
#                                        | RSS: 0.0
#                                        | Number of nodes: 59
# @*************************************** Condition: sulphates <= 0.47
#                                           | Prediction: 4.714
#                                           | RSS: 0.0
#                                           | Number of nodes: 7
# @****************************************** Condition: volatile_acidity <= 0.645
#                                              | Prediction: 5.0
#                                              | RSS: 0.0
#                                              | Number of nodes: 5
# @****************************************** Condition: volatile_acidity > 0.645
#                                              | Prediction: 4.0
#                                              | RSS: 0.0
#                                              | Number of nodes: 2
# @*************************************** Condition: sulphates > 0.47
#                                           | Prediction: 4.962
#                                           | RSS: 0.0
#                                           | Number of nodes: 52
# @****************************************** Condition: alcohol <= 9.35
#                                              | Prediction: 4.833
#                                              | RSS: 0.0
#                                              | Number of nodes: 12
# @********************************************* Condition: residual_sugar <= 2.15
#                                                 | Prediction: 4.0
#                                                 | RSS: 0.0
#                                                 | Number of nodes: 1
# @********************************************* Condition: residual_sugar > 2.15
#                                                 | Prediction: 4.909
#                                                 | RSS: 0.01
#                                                 | Number of nodes: 11
# @************************************************ Condition: sulphates <= 0.515
#                                                    | Prediction: 4.5
#                                                    | RSS: 0.12
#                                                    | Number of nodes: 2
# @************************************************ Condition: sulphates > 0.515
#                                                    | Prediction: 5.0
#                                                    | RSS: 0.0
#                                                    | Number of nodes: 9
# @****************************************** Condition: alcohol > 9.35
#                                              | Prediction: 5.0
#                                              | RSS: 0.0
#                                              | Number of nodes: 40
# @********************************* Condition: residual_sugar > 4.25
#                                     | Prediction: 4.0
#                                     | RSS: 0.0
#                                     | Number of nodes: 1
# @******************************* Condition: density > 0.999
#                                   | Prediction: 5.125
#                                   | RSS: 0.0
#                                   | Number of nodes: 24
# @********************************* Condition: citric_acid <= 0.13
#                                     | Prediction: 5.75
#                                     | RSS: 0.05
#                                     | Number of nodes: 4
# @********************************* Condition: citric_acid > 0.13
#                                     | Prediction: 5.0
#                                     | RSS: 0.0
#                                     | Number of nodes: 20
# @******************* Condition: density > 1.0
#                       | Prediction: 5.667
#                       | RSS: 0.07
#                       | Number of nodes: 3
# @************** Condition: pH > 3.54
#                  | Prediction: 6.0
#                  | RSS: 0.0
#                  | Number of nodes: 3
# @*********** Condition: alcohol > 9.75
#               | Prediction: 5.359
#               | RSS: 0.0
#               | Number of nodes: 92
# @************** Condition: volatile_acidity <= 0.738
#                  | Prediction: 5.479
#                  | RSS: 0.0
#                  | Number of nodes: 71
# @**************** Condition: citric_acid <= 0.015
#                    | Prediction: 6.4
#                    | RSS: 0.13
#                    | Number of nodes: 5
# @**************** Condition: citric_acid > 0.015
#                    | Prediction: 5.409
#                    | RSS: 0.0
#                    | Number of nodes: 66
# @******************* Condition: volatile_acidity <= 0.345
#                       | Prediction: 6.0
#                       | RSS: 0.0
#                       | Number of nodes: 6
# @******************* Condition: volatile_acidity > 0.345
#                       | Prediction: 5.35
#                       | RSS: 0.0
#                       | Number of nodes: 60
# @********************** Condition: fixed_acidity <= 7.55
#                          | Prediction: 5.0
#                          | RSS: 0.0
#                          | Number of nodes: 17
# @************************* Condition: volatile_acidity <= 0.385
#                             | Prediction: 4.0
#                             | RSS: 0.0
#                             | Number of nodes: 1
# @************************* Condition: volatile_acidity > 0.385
#                             | Prediction: 5.062
#                             | RSS: 0.01
#                             | Number of nodes: 16
# @**************************** Condition: sulphates <= 0.545
#                                | Prediction: 5.0
#                                | RSS: 0.0
#                                | Number of nodes: 14
# @**************************** Condition: sulphates > 0.545
#                                | Prediction: 5.5
#                                | RSS: 0.12
#                                | Number of nodes: 2
# @********************** Condition: fixed_acidity > 7.55
#                          | Prediction: 5.488
#                          | RSS: 0.0
#                          | Number of nodes: 43
# @************************* Condition: fixed_acidity <= 8.1
#                             | Prediction: 5.857
#                             | RSS: 0.01
#                             | Number of nodes: 14
# @**************************** Condition: sulphates <= 0.565
#                                | Prediction: 6.0
#                                | RSS: 0.0
#                                | Number of nodes: 11
# @**************************** Condition: sulphates > 0.565
#                                | Prediction: 5.333
#                                | RSS: 0.07
#                                | Number of nodes: 3
# @************************* Condition: fixed_acidity > 8.1
#                             | Prediction: 5.31
#                             | RSS: 0.0
#                             | Number of nodes: 29
# @**************************** Condition: citric_acid <= 0.245
#                                | Prediction: 5.615
#                                | RSS: 0.01
#                                | Number of nodes: 13
# @******************************* Condition: total_sulfur_dioxide <= 17.5
#                                   | Prediction: 4.667
#                                   | RSS: 0.07
#                                   | Number of nodes: 3
# @******************************* Condition: total_sulfur_dioxide > 17.5
#                                   | Prediction: 5.9
#                                   | RSS: 0.0
#                                   | Number of nodes: 10
# @********************************* Condition: residual_sugar <= 1.8
#                                     | Prediction: 5.0
#                                     | RSS: 0.0
#                                     | Number of nodes: 1
# @********************************* Condition: residual_sugar > 1.8
#                                     | Prediction: 6.0
#                                     | RSS: 0.0
#                                     | Number of nodes: 9
# @**************************** Condition: citric_acid > 0.245
#                                | Prediction: 5.062
#                                | RSS: 0.0
#                                | Number of nodes: 16
# @******************************* Condition: residual_sugar <= 3.2
#                                   | Prediction: 5.0
#                                   | RSS: 0.0
#                                   | Number of nodes: 15
# @********************************* Condition: chlorides <= 0.054
#                                     | Prediction: 6.0
#                                     | RSS: 0.0
#                                     | Number of nodes: 1
# @********************************* Condition: chlorides > 0.054
#                                     | Prediction: 4.929
#                                     | RSS: 0.01
#                                     | Number of nodes: 14
# @************************************ Condition: pH <= 3.305
#                                        | Prediction: 5.0
#                                        | RSS: 0.0
#                                        | Number of nodes: 12
# @************************************ Condition: pH > 3.305
#                                        | Prediction: 4.5
#                                        | RSS: 0.12
#                                        | Number of nodes: 2
# @******************************* Condition: residual_sugar > 3.2
#                                   | Prediction: 6.0
#                                   | RSS: 0.0
#                                   | Number of nodes: 1
# @************** Condition: volatile_acidity > 0.738
#                  | Prediction: 4.952
#                  | RSS: 0.0
#                  | Number of nodes: 21
# @**************** Condition: fixed_acidity <= 6.2
#                    | Prediction: 4.0
#                    | RSS: 0.0
#                    | Number of nodes: 2
# @**************** Condition: fixed_acidity > 6.2
#                    | Prediction: 5.053
#                    | RSS: 0.0
#                    | Number of nodes: 19
# @******************* Condition: volatile_acidity <= 1.012
#                       | Prediction: 4.933
#                       | RSS: 0.0
#                       | Number of nodes: 15
# @********************** Condition: citric_acid <= 0.255
#                          | Prediction: 5.0
#                          | RSS: 0.0
#                          | Number of nodes: 12
# @********************** Condition: citric_acid > 0.255
#                          | Prediction: 4.667
#                          | RSS: 0.07
#                          | Number of nodes: 3
# @******************* Condition: volatile_acidity > 1.012
#                       | Prediction: 5.5
#                       | RSS: 0.06
#                       | Number of nodes: 4
# @******** Condition: density > 1.001
#            | Prediction: 3.0
#            | RSS: 0.0
#            | Number of nodes: 1
# @***** Condition: sulphates > 0.575
#         | Prediction: 5.517
#         | RSS: 0.0
#         | Number of nodes: 501
# @******** Condition: volatile_acidity <= 0.405
#            | Prediction: 5.845
#            | RSS: 0.0
#            | Number of nodes: 129
# @*********** Condition: density <= 0.997
#               | Prediction: 5.214
#               | RSS: 0.0
#               | Number of nodes: 14
# @************** Condition: chlorides <= 0.094
#                  | Prediction: 5.154
#                  | RSS: 0.0
#                  | Number of nodes: 13
# @**************** Condition: citric_acid <= 0.335
#                    | Prediction: 5.0
#                    | RSS: 0.0
#                    | Number of nodes: 8
# @**************** Condition: citric_acid > 0.335
#                    | Prediction: 5.4
#                    | RSS: 0.05
#                    | Number of nodes: 5
# @************** Condition: chlorides > 0.094
#                  | Prediction: 6.0
#                  | RSS: 0.0
#                  | Number of nodes: 1
# @*********** Condition: density > 0.997
#               | Prediction: 5.922
#               | RSS: 0.0
#               | Number of nodes: 115
# @************** Condition: chlorides <= 0.096
#                  | Prediction: 6.033
#                  | RSS: 0.0
#                  | Number of nodes: 90
# @**************** Condition: sulphates <= 0.71
#                    | Prediction: 5.814
#                    | RSS: 0.0
#                    | Number of nodes: 43
# @******************* Condition: total_sulfur_dioxide <= 83.0
#                       | Prediction: 5.857
#                       | RSS: 0.0
#                       | Number of nodes: 42
# @********************** Condition: chlorides <= 0.094
#                          | Prediction: 5.829
#                          | RSS: 0.0
#                          | Number of nodes: 41
# @************************* Condition: residual_sugar <= 1.95
#                             | Prediction: 6.067
#                             | RSS: 0.0
#                             | Number of nodes: 15
# @**************************** Condition: fixed_acidity <= 11.8
#                                | Prediction: 6.0
#                                | RSS: 0.0
#                                | Number of nodes: 14
# @**************************** Condition: fixed_acidity > 11.8
#                                | Prediction: 7.0
#                                | RSS: 0.0
#                                | Number of nodes: 1
# @************************* Condition: residual_sugar > 1.95
#                             | Prediction: 5.692
#                             | RSS: 0.0
#                             | Number of nodes: 26
# @**************************** Condition: chlorides <= 0.08
#                                | Prediction: 5.286
#                                | RSS: 0.01
#                                | Number of nodes: 7
# @******************************* Condition: fixed_acidity <= 10.4
#                                   | Prediction: 5.0
#                                   | RSS: 0.0
#                                   | Number of nodes: 4
# @******************************* Condition: fixed_acidity > 10.4
#                                   | Prediction: 5.667
#                                   | RSS: 0.07
#                                   | Number of nodes: 3
# @**************************** Condition: chlorides > 0.08
#                                | Prediction: 5.842
#                                | RSS: 0.0
#                                | Number of nodes: 19
# @******************************* Condition: residual_sugar <= 2.05
#                                   | Prediction: 5.5
#                                   | RSS: 0.06
#                                   | Number of nodes: 4
# @******************************* Condition: residual_sugar > 2.05
#                                   | Prediction: 5.933
#                                   | RSS: 0.01
#                                   | Number of nodes: 15
# @********************************* Condition: total_sulfur_dioxide <= 66.5
#                                     | Prediction: 6.0
#                                     | RSS: 0.0
#                                     | Number of nodes: 13
# @********************************* Condition: total_sulfur_dioxide > 66.5
#                                     | Prediction: 5.5
#                                     | RSS: 0.12
#                                     | Number of nodes: 2
# @********************** Condition: chlorides > 0.094
#                          | Prediction: 7.0
#                          | RSS: 0.0
#                          | Number of nodes: 1
# @******************* Condition: total_sulfur_dioxide > 83.0
#                       | Prediction: 4.0
#                       | RSS: 0.0
#                       | Number of nodes: 1
# @**************** Condition: sulphates > 0.71
#                    | Prediction: 6.234
#                    | RSS: 0.0
#                    | Number of nodes: 47
# @******************* Condition: free_sulfur_dioxide <= 14.5
#                       | Prediction: 6.4
#                       | RSS: 0.0
#                       | Number of nodes: 30
# @********************** Condition: total_sulfur_dioxide <= 28.5
#                          | Prediction: 6.208
#                          | RSS: 0.0
#                          | Number of nodes: 24
# @************************* Condition: chlorides <= 0.084
#                             | Prediction: 6.261
#                             | RSS: 0.0
#                             | Number of nodes: 23
# @**************************** Condition: total_sulfur_dioxide <= 24.5
#                                | Prediction: 6.462
#                                | RSS: 0.0
#                                | Number of nodes: 13
# @******************************* Condition: volatile_acidity <= 0.33
#                                   | Prediction: 6.6
#                                   | RSS: 0.0
#                                   | Number of nodes: 10
# @********************************* Condition: pH <= 3.045
#                                     | Prediction: 6.0
#                                     | RSS: 0.0
#                                     | Number of nodes: 2
# @********************************* Condition: pH > 3.045
#                                     | Prediction: 6.75
#                                     | RSS: 0.0
#                                     | Number of nodes: 8
# @************************************ Condition: chlorides <= 0.078
#                                        | Prediction: 6.857
#                                        | RSS: 0.0
#                                        | Number of nodes: 7
# @*************************************** Condition: residual_sugar <= 3.1
#                                           | Prediction: 7.0
#                                           | RSS: 0.0
#                                           | Number of nodes: 6
# @*************************************** Condition: residual_sugar > 3.1
#                                           | Prediction: 6.0
#                                           | RSS: 0.0
#                                           | Number of nodes: 1
# @************************************ Condition: chlorides > 0.078
#                                        | Prediction: 6.0
#                                        | RSS: 0.0
#                                        | Number of nodes: 1
# @******************************* Condition: volatile_acidity > 0.33
#                                   | Prediction: 6.0
#                                   | RSS: 0.0
#                                   | Number of nodes: 3
# @**************************** Condition: total_sulfur_dioxide > 24.5
#                                | Prediction: 6.0
#                                | RSS: 0.0
#                                | Number of nodes: 10
# @************************* Condition: chlorides > 0.084
#                             | Prediction: 5.0
#                             | RSS: 0.0
#                             | Number of nodes: 1
# @********************** Condition: total_sulfur_dioxide > 28.5
#                          | Prediction: 7.167
#                          | RSS: 0.0
#                          | Number of nodes: 6
# @************************* Condition: fixed_acidity <= 12.55
#                             | Prediction: 7.0
#                             | RSS: 0.0
#                             | Number of nodes: 5
# @************************* Condition: fixed_acidity > 12.55
#                             | Prediction: 8.0
#                             | RSS: 0.0
#                             | Number of nodes: 1
# @******************* Condition: free_sulfur_dioxide > 14.5
#                       | Prediction: 5.941
#                       | RSS: 0.0
#                       | Number of nodes: 17
# @********************** Condition: citric_acid <= 0.57
#                          | Prediction: 6.067
#                          | RSS: 0.0
#                          | Number of nodes: 15
# @************************* Condition: free_sulfur_dioxide <= 33.0
#                             | Prediction: 5.909
#                             | RSS: 0.0
#                             | Number of nodes: 11
# @**************************** Condition: total_sulfur_dioxide <= 81.5
#                                | Prediction: 6.0
#                                | RSS: 0.0
#                                | Number of nodes: 10
# @**************************** Condition: total_sulfur_dioxide > 81.5
#                                | Prediction: 5.0
#                                | RSS: 0.0
#                                | Number of nodes: 1
# @************************* Condition: free_sulfur_dioxide > 33.0
#                             | Prediction: 6.5
#                             | RSS: 0.06
#                             | Number of nodes: 4
# @********************** Condition: citric_acid > 0.57
#                          | Prediction: 5.0
#                          | RSS: 0.0
#                          | Number of nodes: 2
# @************** Condition: chlorides > 0.096
#                  | Prediction: 5.52
#                  | RSS: 0.0
#                  | Number of nodes: 25
# @**************** Condition: fixed_acidity <= 8.0
#                    | Prediction: 6.25
#                    | RSS: 0.05
#                    | Number of nodes: 4
# @**************** Condition: fixed_acidity > 8.0
#                    | Prediction: 5.381
#                    | RSS: 0.0
#                    | Number of nodes: 21
# @******************* Condition: fixed_acidity <= 10.65
#                       | Prediction: 5.091
#                       | RSS: 0.0
#                       | Number of nodes: 11
# @********************** Condition: chlorides <= 0.286
#                          | Prediction: 5.0
#                          | RSS: 0.0
#                          | Number of nodes: 10
# @********************** Condition: chlorides > 0.286
#                          | Prediction: 6.0
#                          | RSS: 0.0
#                          | Number of nodes: 1
# @******************* Condition: fixed_acidity > 10.65
#                       | Prediction: 5.7
#                       | RSS: 0.0
#                       | Number of nodes: 10
# @********************** Condition: sulphates <= 0.73
#                          | Prediction: 5.0
#                          | RSS: 0.0
#                          | Number of nodes: 3
# @********************** Condition: sulphates > 0.73
#                          | Prediction: 6.0
#                          | RSS: 0.0
#                          | Number of nodes: 7
# @******** Condition: volatile_acidity > 0.405
#            | Prediction: 5.403
#            | RSS: 0.0
#            | Number of nodes: 372
# @*********** Condition: total_sulfur_dioxide <= 46.5
#               | Prediction: 5.567
#               | RSS: 0.0
#               | Number of nodes: 201
# @************** Condition: alcohol <= 8.7
#                  | Prediction: 3.0
#                  | RSS: 0.0
#                  | Number of nodes: 1
# @************** Condition: alcohol > 8.7
#                  | Prediction: 5.58
#                  | RSS: 0.0
#                  | Number of nodes: 200
# @**************** Condition: residual_sugar <= 5.2
#                    | Prediction: 5.554
#                    | RSS: 0.0
#                    | Number of nodes: 195
# @******************* Condition: free_sulfur_dioxide <= 21.5
#                       | Prediction: 5.529
#                       | RSS: 0.0
#                       | Number of nodes: 191
# @********************** Condition: sulphates <= 1.07
#                          | Prediction: 5.551
#                          | RSS: 0.0
#                          | Number of nodes: 185
# @************************* Condition: pH <= 3.475
#                             | Prediction: 5.616
#                             | RSS: 0.0
#                             | Number of nodes: 151
# @**************************** Condition: chlorides <= 0.08
#                                | Prediction: 5.487
#                                | RSS: 0.0
#                                | Number of nodes: 76
# @******************************* Condition: citric_acid <= 0.195
#                                   | Prediction: 5.707
#                                   | RSS: 0.0
#                                   | Number of nodes: 41
# @********************************* Condition: total_sulfur_dioxide <= 37.0
#                                     | Prediction: 5.8
#                                     | RSS: 0.0
#                                     | Number of nodes: 35
# @************************************ Condition: fixed_acidity <= 6.55
#                                        | Prediction: 5.0
#                                        | RSS: 0.0
#                                        | Number of nodes: 3
# @************************************ Condition: fixed_acidity > 6.55
#                                        | Prediction: 5.875
#                                        | RSS: 0.0
#                                        | Number of nodes: 32
# @*************************************** Condition: free_sulfur_dioxide <= 4.0
#                                           | Prediction: 7.0
#                                           | RSS: 0.0
#                                           | Number of nodes: 1
# @*************************************** Condition: free_sulfur_dioxide > 4.0
#                                           | Prediction: 5.839
#                                           | RSS: 0.0
#                                           | Number of nodes: 31
# @****************************************** Condition: residual_sugar <= 2.25
#                                              | Prediction: 5.92
#                                              | RSS: 0.0
#                                              | Number of nodes: 25
# @********************************************* Condition: chlorides <= 0.058
#                                                 | Prediction: 5.0
#                                                 | RSS: 0.0
#                                                 | Number of nodes: 1
# @********************************************* Condition: chlorides > 0.058
#                                                 | Prediction: 5.958
#                                                 | RSS: 0.0
#                                                 | Number of nodes: 24
# @************************************************ Condition: pH <= 3.28
#                                                    | Prediction: 5.75
#                                                    | RSS: 0.05
#                                                    | Number of nodes: 4
# @************************************************ Condition: pH > 3.28
#                                                    | Prediction: 6.0
#                                                    | RSS: 0.0
#                                                    | Number of nodes: 20
# @****************************************** Condition: residual_sugar > 2.25
#                                              | Prediction: 5.5
#                                              | RSS: 0.0
#                                              | Number of nodes: 6
# @********************************************* Condition: total_sulfur_dioxide <= 28.0
#                                                 | Prediction: 5.0
#                                                 | RSS: 0.0
#                                                 | Number of nodes: 3
# @********************************************* Condition: total_sulfur_dioxide > 28.0
#                                                 | Prediction: 6.0
#                                                 | RSS: 0.0
#                                                 | Number of nodes: 3
# @********************************* Condition: total_sulfur_dioxide > 37.0
#                                     | Prediction: 5.167
#                                     | RSS: 0.0
#                                     | Number of nodes: 6
# @************************************ Condition: citric_acid <= 0.085
#                                        | Prediction: 6.0
#                                        | RSS: 0.0
#                                        | Number of nodes: 1
# @************************************ Condition: citric_acid > 0.085
#                                        | Prediction: 5.0
#                                        | RSS: 0.0
#                                        | Number of nodes: 5
# @******************************* Condition: citric_acid > 0.195
#                                   | Prediction: 5.229
#                                   | RSS: 0.0
#                                   | Number of nodes: 35
# @********************************* Condition: sulphates <= 0.7
#                                     | Prediction: 5.138
#                                     | RSS: 0.0
#                                     | Number of nodes: 29
# @************************************ Condition: chlorides <= 0.064
#                                        | Prediction: 5.5
#                                        | RSS: 0.0
#                                        | Number of nodes: 6
# @*************************************** Condition: citric_acid <= 0.435
#                                           | Prediction: 5.0
#                                           | RSS: 0.0
#                                           | Number of nodes: 3
# @*************************************** Condition: citric_acid > 0.435
#                                           | Prediction: 6.0
#                                           | RSS: 0.0
#                                           | Number of nodes: 3
# @************************************ Condition: chlorides > 0.064
#                                        | Prediction: 5.043
#                                        | RSS: 0.01
#                                        | Number of nodes: 23
# @*************************************** Condition: citric_acid <= 0.575
#                                           | Prediction: 5.0
#                                           | RSS: 0.01
#                                           | Number of nodes: 21
# @****************************************** Condition: citric_acid <= 0.495
#                                              | Prediction: 5.053
#                                              | RSS: 0.0
#                                              | Number of nodes: 19
# @********************************************* Condition: pH <= 3.375
#                                                 | Prediction: 5.0
#                                                 | RSS: 0.0
#                                                 | Number of nodes: 15
# @********************************************* Condition: pH > 3.375
#                                                 | Prediction: 5.25
#                                                 | RSS: 0.05
#                                                 | Number of nodes: 4
# @****************************************** Condition: citric_acid > 0.495
#                                              | Prediction: 4.5
#                                              | RSS: 0.12
#                                              | Number of nodes: 2
# @*************************************** Condition: citric_acid > 0.575
#                                           | Prediction: 5.5
#                                           | RSS: 0.12
#                                           | Number of nodes: 2
# @********************************* Condition: sulphates > 0.7
#                                     | Prediction: 5.667
#                                     | RSS: 0.0
#                                     | Number of nodes: 6
# @************************************ Condition: free_sulfur_dioxide <= 7.0
#                                        | Prediction: 5.0
#                                        | RSS: 0.0
#                                        | Number of nodes: 2
# @************************************ Condition: free_sulfur_dioxide > 7.0
#                                        | Prediction: 6.0
#                                        | RSS: 0.0
#                                        | Number of nodes: 4
# @**************************** Condition: chlorides > 0.08
#                                | Prediction: 5.747
#                                | RSS: 0.0
#                                | Number of nodes: 75
# @******************************* Condition: chlorides <= 0.085
#                                   | Prediction: 6.056
#                                   | RSS: 0.0
#                                   | Number of nodes: 18
# @********************************* Condition: fixed_acidity <= 7.6
#                                     | Prediction: 6.25
#                                     | RSS: 0.05
#                                     | Number of nodes: 4
# @********************************* Condition: fixed_acidity > 7.6
#                                     | Prediction: 6.0
#                                     | RSS: 0.0
#                                     | Number of nodes: 14
# @******************************* Condition: chlorides > 0.085
#                                   | Prediction: 5.649
#                                   | RSS: 0.0
#                                   | Number of nodes: 57
# @********************************* Condition: volatile_acidity <= 0.878
#                                     | Prediction: 5.625
#                                     | RSS: 0.0
#                                     | Number of nodes: 56
# @************************************ Condition: total_sulfur_dioxide <= 43.5
#                                        | Prediction: 5.56
#                                        | RSS: 0.0
#                                        | Number of nodes: 50
# @*************************************** Condition: fixed_acidity <= 11.65
# ...
# @**************** Condition: horsepower > 115.0
#                    | Prediction: 16.0
#                    | RSS: 0.12
#                    | Number of nodes: 2
# @************** Condition: model_year != 76.0
#                  | Prediction: 17.897
#                  | RSS: 0.01
#                  | Number of nodes: 36
# @**************** Condition: model_year == 77.0
#                    | Prediction: 18.5
#                    | RSS: 0.3
#                    | Number of nodes: 5
# @**************** Condition: model_year != 77.0
#                    | Prediction: 17.8
#                    | RSS: 0.0
#                    | Number of nodes: 31
# @******************* Condition: model_year == 78.0
#                       | Prediction: 19.311
#                       | RSS: 0.02
#                       | Number of nodes: 9
# @********************** Condition: horsepower <= 115.0
#                          | Prediction: 19.814
#                          | RSS: 0.01
#                          | Number of nodes: 7
# @************************* Condition: weight <= 3482.5
#                             | Prediction: 20.18
#                             | RSS: 0.04
#                             | Number of nodes: 5
# @************************* Condition: weight > 3482.5
#                             | Prediction: 18.9
#                             | RSS: 0.04
#                             | Number of nodes: 2
# @********************** Condition: horsepower > 115.0
#                          | Prediction: 17.55
#                          | RSS: 0.15
#                          | Number of nodes: 2
# @******************* Condition: model_year != 78.0
#                       | Prediction: 17.182
#                       | RSS: 0.0
#                       | Number of nodes: 22
# @********************** Condition: acceleration <= 16.75
#                          | Prediction: 18.182
#                          | RSS: 0.02
#                          | Number of nodes: 11
# @************************* Condition: weight <= 3315.5
#                             | Prediction: 18.714
#                             | RSS: 0.0
#                             | Number of nodes: 7
# @**************************** Condition: cylinders == 8.0
#                                | Prediction: 20.0
#                                | RSS: 0.0
#                                | Number of nodes: 1
# @**************************** Condition: cylinders != 8.0
#                                | Prediction: 18.5
#                                | RSS: 0.01
#                                | Number of nodes: 6
# @******************************* Condition: weight <= 3201.5
#                                   | Prediction: 18.0
#                                   | RSS: 0.0
#                                   | Number of nodes: 2
# @******************************* Condition: weight > 3201.5
#                                   | Prediction: 18.75
#                                   | RSS: 0.05
#                                   | Number of nodes: 4
# @************************* Condition: weight > 3315.5
#                             | Prediction: 17.25
#                             | RSS: 0.17
#                             | Number of nodes: 4
# @********************** Condition: acceleration > 16.75
#                          | Prediction: 16.182
#                          | RSS: 0.02
#                          | Number of nodes: 11
# @************************* Condition: displacement <= 241.0
#                             | Prediction: 18.0
#                             | RSS: 0.22
#                             | Number of nodes: 3
# @************************* Condition: displacement > 241.0
#                             | Prediction: 15.5
#                             | RSS: 0.0
#                             | Number of nodes: 8
# @**************************** Condition: acceleration <= 18.75
#                                | Prediction: 15.8
#                                | RSS: 0.03
#                                | Number of nodes: 5
# @**************************** Condition: acceleration > 18.75
#                                | Prediction: 15.0
#                                | RSS: 0.0
#                                | Number of nodes: 3
# @***** Condition: horsepower > 127.0
#         | Prediction: 14.536
#         | RSS: 0.0
#         | Number of nodes: 97
# @******** Condition: model_year == 77.0
#            | Prediction: 15.857
#            | RSS: 0.0
#            | Number of nodes: 7
# @*********** Condition: weight <= 4010.0
#               | Prediction: 17.5
#               | RSS: 0.0
#               | Number of nodes: 1
# @*********** Condition: weight > 4010.0
#               | Prediction: 15.583
#               | RSS: 0.0
#               | Number of nodes: 6
# @************** Condition: displacement <= 310.0
#                  | Prediction: 15.0
#                  | RSS: 0.0
#                  | Number of nodes: 1
# @************** Condition: displacement > 310.0
#                  | Prediction: 15.7
#                  | RSS: 0.01
#                  | Number of nodes: 5
# @******** Condition: model_year != 77.0
#            | Prediction: 14.433
#            | RSS: 0.0
#            | Number of nodes: 90
# @*********** Condition: model_year == 78.0
#               | Prediction: 18.329
#               | RSS: 0.04
#               | Number of nodes: 7
# @************** Condition: acceleration <= 13.3
#                  | Prediction: 19.225
#                  | RSS: 0.14
#                  | Number of nodes: 4
# @************** Condition: acceleration > 13.3
#                  | Prediction: 17.133
#                  | RSS: 0.15
#                  | Number of nodes: 3
# @*********** Condition: model_year != 78.0
#               | Prediction: 14.105
#               | RSS: 0.0
#               | Number of nodes: 83
# @************** Condition: weight <= 4361.5
#                  | Prediction: 14.85
#                  | RSS: 0.0
#                  | Number of nodes: 52
# @**************** Condition: model_year == 79.0
#                    | Prediction: 17.171
#                    | RSS: 0.03
#                    | Number of nodes: 7
# @******************* Condition: weight <= 3947.5
#                       | Prediction: 17.825
#                       | RSS: 0.08
#                       | Number of nodes: 4
# @******************* Condition: weight > 3947.5
#                       | Prediction: 16.3
#                       | RSS: 0.12
#                       | Number of nodes: 3
# @**************** Condition: model_year != 79.0
#                    | Prediction: 14.489
#                    | RSS: 0.0
#                    | Number of nodes: 45
# @******************* Condition: weight <= 3533.5
#                       | Prediction: 15.857
#                       | RSS: 0.06
#                       | Number of nodes: 7
# @********************** Condition: weight <= 3416.0
#                          | Prediction: 14.0
#                          | RSS: 0.22
#                          | Number of nodes: 3
# @********************** Condition: weight > 3416.0
#                          | Prediction: 17.25
#                          | RSS: 0.17
#                          | Number of nodes: 4
# @******************* Condition: weight > 3533.5
#                       | Prediction: 14.237
#                       | RSS: 0.0
#                       | Number of nodes: 38
# @********************** Condition: weight <= 4132.0
#                          | Prediction: 13.957
#                          | RSS: 0.0
#                          | Number of nodes: 23
# @************************* Condition: model_year == 73.0
#                             | Prediction: 13.5
#                             | RSS: 0.0
#                             | Number of nodes: 8
# @**************************** Condition: horsepower <= 177.5
#                                | Prediction: 13.857
#                                | RSS: 0.02
#                                | Number of nodes: 7
# @******************************* Condition: horsepower <= 162.5
#                                   | Prediction: 14.2
#                                   | RSS: 0.11
#                                   | Number of nodes: 5
# @******************************* Condition: horsepower > 162.5
#                                   | Prediction: 13.0
#                                   | RSS: 0.0
#                                   | Number of nodes: 2
# @**************************** Condition: horsepower > 177.5
#                                | Prediction: 11.0
#                                | RSS: 0.0
#                                | Number of nodes: 1
# @************************* Condition: model_year != 73.0
#                             | Prediction: 14.2
#                             | RSS: 0.0
#                             | Number of nodes: 15
# @**************************** Condition: acceleration <= 11.75
#                                | Prediction: 15.167
#                                | RSS: 0.01
#                                | Number of nodes: 6
# @******************************* Condition: displacement <= 322.0
#                                   | Prediction: 17.0
#                                   | RSS: 0.0
#                                   | Number of nodes: 1
# @******************************* Condition: displacement > 322.0
#                                   | Prediction: 14.8
#                                   | RSS: 0.03
#                                   | Number of nodes: 5
# @**************************** Condition: acceleration > 11.75
#                                | Prediction: 13.556
#                                | RSS: 0.01
#                                | Number of nodes: 9
# @******************************* Condition: model_year == 76.0
#                                   | Prediction: 13.0
#                                   | RSS: 0.0
#                                   | Number of nodes: 4
# @******************************* Condition: model_year != 76.0
#                                   | Prediction: 14.0
#                                   | RSS: 0.08
#                                   | Number of nodes: 5
# @********************** Condition: weight > 4132.0
#                          | Prediction: 14.667
#                          | RSS: 0.04
#                          | Number of nodes: 15
# @************************* Condition: model_year == 73.0
#                             | Prediction: 15.0
#                             | RSS: 0.5
#                             | Number of nodes: 2
# @************************* Condition: model_year != 73.0
#                             | Prediction: 14.615
#                             | RSS: 0.04
#                             | Number of nodes: 13
# @**************************** Condition: model_year == 74.0
#                                | Prediction: 15.0
#                                | RSS: 0.5
#                                | Number of nodes: 2
# @**************************** Condition: model_year != 74.0
#                                | Prediction: 14.545
#                                | RSS: 0.05
#                                | Number of nodes: 11
# @******************************* Condition: model_year == 76.0
#                                   | Prediction: 16.0
#                                   | RSS: 0.5
#                                   | Number of nodes: 3
# @******************************* Condition: model_year != 76.0
#                                   | Prediction: 14.0
#                                   | RSS: 0.0
#                                   | Number of nodes: 8
# @********************************* Condition: displacement <= 310.0
#                                     | Prediction: 13.0
#                                     | RSS: 0.0
#                                     | Number of nodes: 1
# @********************************* Condition: displacement > 310.0
#                                     | Prediction: 14.143
#                                     | RSS: 0.0
#                                     | Number of nodes: 7
# @************************************ Condition: displacement <= 334.0
#                                        | Prediction: 15.0
#                                        | RSS: 0.0
#                                        | Number of nodes: 1
# @************************************ Condition: displacement > 334.0
#                                        | Prediction: 14.0
#                                        | RSS: 0.01
#                                        | Number of nodes: 6
# @*************************************** Condition: model_year == 72.0
#                                           | Prediction: 13.0
#                                           | RSS: 0.0
#                                           | Number of nodes: 1
# @*************************************** Condition: model_year != 72.0
#                                           | Prediction: 14.2
#                                           | RSS: 0.03
#                                           | Number of nodes: 5
# @************** Condition: weight > 4361.5
#                  | Prediction: 12.855
#                  | RSS: 0.01
#                  | Number of nodes: 31
# @**************** Condition: model_year == 75.0
#                    | Prediction: 15.25
#                    | RSS: 0.17
#                    | Number of nodes: 4
# @**************** Condition: model_year != 75.0
#                    | Prediction: 12.5
#                    | RSS: 0.0
#                    | Number of nodes: 27
# @******************* Condition: horsepower <= 191.5
#                       | Prediction: 13.083
#                       | RSS: 0.0
#                       | Number of nodes: 18
# @********************** Condition: model_year == 76.0
#                          | Prediction: 16.5
#                          | RSS: 0.0
#                          | Number of nodes: 1
# @********************** Condition: model_year != 76.0
#                          | Prediction: 12.882
#                          | RSS: 0.01
#                          | Number of nodes: 17
# @************************* Condition: weight <= 4826.0
#                             | Prediction: 13.154
#                             | RSS: 0.0
#                             | Number of nodes: 13
# @**************************** Condition: displacement <= 334.0
#                                | Prediction: 14.0
#                                | RSS: 0.0
#                                | Number of nodes: 2
# @**************************** Condition: displacement > 334.0
#                                | Prediction: 13.0
#                                | RSS: 0.01
#                                | Number of nodes: 11
# @******************************* Condition: displacement <= 350.5
#                                   | Prediction: 12.5
#                                   | RSS: 0.06
#                                   | Number of nodes: 4
# @******************************* Condition: displacement > 350.5
#                                   | Prediction: 13.286
#                                   | RSS: 0.01
#                                   | Number of nodes: 7
# @********************************* Condition: horsepower <= 172.5
#                                     | Prediction: 13.0
#                                     | RSS: 0.0
#                                     | Number of nodes: 4
# @********************************* Condition: horsepower > 172.5
#                                     | Prediction: 13.667
#                                     | RSS: 0.07
#                                     | Number of nodes: 3
# @************************* Condition: weight > 4826.0
#                             | Prediction: 12.0
#                             | RSS: 0.12
#                             | Number of nodes: 4
# @******************* Condition: horsepower > 191.5
#                       | Prediction: 11.333
#                       | RSS: 0.04
#                       | Number of nodes: 9
# @********************** Condition: displacement <= 394.5
#                          | Prediction: 10.0
#                          | RSS: 0.12
#                          | Number of nodes: 4
# @********************** Condition: displacement > 394.5
#                          | Prediction: 12.4
#                          | RSS: 0.21
#                          | Number of nodes: 5
#
# RMSE FOR THE TREE CHOSE BY MIN RSS = 8.291296758451532
# ALPHA LIST [0]
